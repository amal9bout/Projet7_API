# %%
pip install Flask
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Flask in c:\users\amal9\appdata\roaming\python\python311\site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from Flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from Flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from Flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from Flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from Flask) (1.8.2)
# Requirement already satisfied: colorama in c:\users\amal9\appdata\roaming\python\python311\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from Jinja2>=3.1.2->Flask) (2.1.5)
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\amal9\appdata\roaming\python\python311\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\amal9\appdata\roaming\python\python311\site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\users\amal9\appdata\roaming\python\python311\site-packages (1.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lightgbm in c:\users\amal9\appdata\roaming\python\python311\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from lightgbm) (2.0.0)
# Requirement already satisfied: scipy in c:\users\amal9\appdata\roaming\python\python311\site-packages (from lightgbm) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\amal9\appdata\roaming\python\python311\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from scikit-learn) (2.0.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.5.0)

# %%
pip install fastapi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastapi in c:\users\amal9\appdata\roaming\python\python311\site-packages (0.111.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (0.37.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (2.7.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (3.10.5)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (2.2.0)
# Requirement already satisfied: uvicorn[standard]>=0.12.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi) (0.30.1)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from email_validator>=2.0.0->fastapi) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Requirement already satisfied: typer>=0.12.3 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: anyio in c:\users\amal9\appdata\roaming\python\python311\site-packages (from httpx>=0.23.0->fastapi) (4.4.0)
# Requirement already satisfied: certifi in c:\users\amal9\appdata\roaming\python\python311\site-packages (from httpx>=0.23.0->fastapi) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\amal9\appdata\roaming\python\python311\site-packages (from httpx>=0.23.0->fastapi) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\amal9\appdata\roaming\python\python311\site-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from jinja2>=2.11.2->fastapi) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.18.4)
# Requirement already satisfied: click>=7.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (8.1.7)
# Requirement already satisfied: colorama>=0.4 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.4.6)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (1.0.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (6.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (12.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install "uvicorn[standard]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: uvicorn[standard] in c:\users\amal9\appdata\roaming\python\python311\site-packages (0.30.1)
# Requirement already satisfied: click>=7.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (0.14.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (0.4.6)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (1.0.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (6.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from uvicorn[standard]) (12.0)
# Requirement already satisfied: anyio>=3.0.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from watchfiles>=0.13->uvicorn[standard]) (4.4.0)
# Requirement already satisfied: idna>=2.8 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pydantic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydantic in c:\users\amal9\appdata\roaming\python\python311\site-packages (2.7.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pydantic) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from pydantic) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pickle
from lightgbm import LGBMClassifier
import pandas as pd
from fastapi import FastAPI
import uvicorn
from pydantic import BaseModel
import joblib
import nest_asyncio
import asyncio

# %%
# Charger le modèle LightGBM
model= joblib.load("C:\\Users\\amal9\\OneDrive\\Documents\\9-Openclassroom\\8-PROJET 7\\GIT\\lightgbm_model_df1.pkl")
# Out:
# C:\Users\amal9\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.2.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
df = pd.read_csv("C:\\Users\\amal9\\OneDrive\\Documents\\9-Openclassroom\\8-PROJET 7\\GIT\\df1_final.csv")

# %%
display(df.head(20))
# Out:
#     EXT_SOURCE_3  EXT_SOURCE_2  PAYMENT_RATE  DAYS_ID_PUBLISH  EXT_SOURCE_1  \
# 0       0.139376      0.262949      0.060749            -2120      0.083037
# 1            NaN      0.622246      0.027598             -291      0.311267
# 2       0.729567      0.555912      0.050000            -2531           NaN
# 3            NaN      0.650442      0.094941            -2437           NaN
# 4            NaN      0.322738      0.042623            -3458           NaN
# 5       0.621226      0.354225      0.056101             -477           NaN
# 6       0.492060      0.724000      0.026463             -619      0.774761
# 7       0.540654      0.714279      0.027500            -2379           NaN
# 8       0.751724      0.205747      0.033176            -3514      0.587334
# 9            NaN      0.746644      0.050000            -3992           NaN
# 10      0.363945      0.651862      0.032455             -738      0.319760
# 11      0.652897      0.555183      0.071975            -2512      0.722044
# 12      0.176653      0.715042      0.072732            -3227      0.464831
# 13      0.770087      0.566907      0.031538            -4911           NaN
# 14           NaN      0.642656      0.042366            -2056      0.721940
# 15      0.678568      0.346634      0.067251            -1368      0.115634
# 16      0.062103      0.236378      0.051314            -3866           NaN
# 17           NaN      0.683513      0.050000            -2427           NaN
# 18      0.556727      0.706428      0.050000            -1259           NaN
# 19      0.477649      0.586617      0.032257            -3964           NaN
#
#     DAYS_REGISTRATION  DAYS_EMPLOYED_PERC  DAYS_BIRTH  DAYS_LAST_PHONE_CHANGE  \
# 0             -3648.0            0.067329       -9461                 -1134.0
# 1             -1186.0            0.070862      -16765                  -828.0
# 2             -4260.0            0.011814      -19046                  -815.0
# 3             -9833.0            0.159905      -19005                  -617.0
# 4             -4311.0            0.152418      -19932                 -1106.0
# 5             -4970.0            0.093737      -16941                 -2536.0
# 6             -1213.0            0.227174      -13778                 -1562.0
# 7             -4597.0            0.023820      -18850                 -1070.0
# 8             -7427.0                 NaN      -20099                     0.0
# 9            -14437.0            0.139540      -14469                 -1673.0
# 10            -4427.0            0.066588      -10197                  -844.0
# 11            -5246.0                 NaN      -20417                 -2396.0
# 12             -311.0            0.202173      -13439                 -2370.0
# 13             -643.0            0.214965      -14086                    -4.0
# 14             -615.0            0.013920      -14583                  -188.0
# 15            -3494.0            0.132562       -8728                  -925.0
# 16            -6392.0            0.101848      -12931                    -3.0
# 17            -4143.0            0.019538       -9776                 -2811.0
# 18            -8751.0            0.440456      -17718                  -239.0
# 19            -1021.0            0.179591      -11348                 -1850.0
#
#     REGION_POPULATION_RELATIVE  ...  PREV_AMT_GOODS_PRICE_MIN  \
# 0                     0.018801  ...                       NaN
# 1                     0.003541  ...                       NaN
# 2                     0.010032  ...                       NaN
# 3                     0.008019  ...                       NaN
# 4                     0.028663  ...                       NaN
# 5                     0.035792  ...                       NaN
# 6                     0.035792  ...                   98239.5
# 7                     0.003122  ...                       NaN
# 8                     0.018634  ...                       NaN
# 9                     0.019689  ...                       NaN
# 10                    0.022800  ...                       NaN
# 11                    0.015221  ...                       NaN
# 12                    0.031329  ...                       NaN
# 13                    0.016612  ...                       NaN
# 14                    0.010006  ...                       NaN
# 15                    0.020713  ...                       NaN
# 16                    0.018634  ...                       NaN
# 17                    0.010966  ...                       NaN
# 18                    0.046220  ...                       NaN
# 19                    0.015221  ...                       NaN
#
#     ORGANIZATION_TYPE_Industrytype1  PREV_AMT_GOODS_PRICE_MAX  \
# 0                             False                       NaN
# 1                             False                       NaN
# 2                             False                       NaN
# 3                             False                       NaN
# 4                             False                       NaN
# 5                             False                       NaN
# 6                             False                   98239.5
# 7                             False                       NaN
# 8                             False                       NaN
# 9                             False                       NaN
# 10                            False                       NaN
# 11                            False                       NaN
# 12                            False                       NaN
# 13                            False                       NaN
# 14                            False                       NaN
# 15                            False                       NaN
# 16                            False                       NaN
# 17                            False                       NaN
# 18                            False                       NaN
# 19                            False                       NaN
#
#     PREV_AMT_DOWN_PAYMENT_MIN  PREV_AMT_DOWN_PAYMENT_MEAN  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# 5                         NaN                         NaN
# 6                         0.0                         0.0
# 7                         NaN                         NaN
# 8                         NaN                         NaN
# 9                         NaN                         NaN
# 10                        NaN                         NaN
# 11                        NaN                         NaN
# 12                        NaN                         NaN
# 13                        NaN                         NaN
# 14                        NaN                         NaN
# 15                        NaN                         NaN
# 16                        NaN                         NaN
# 17                        NaN                         NaN
# 18                        NaN                         NaN
# 19                        NaN                         NaN
#
#     PREV_AMT_DOWN_PAYMENT_MAX  PREV_AMT_CREDIT_MEAN  PREV_AMT_CREDIT_MAX  \
# 0                         NaN                   NaN                  NaN
# 1                         NaN                   NaN                  NaN
# 2                         NaN                   NaN                  NaN
# 3                         NaN                   NaN                  NaN
# 4                         NaN                   NaN                  NaN
# 5                         NaN                   NaN                  NaN
# 6                         0.0               98239.5              98239.5
# 7                         NaN                   NaN                  NaN
# 8                         NaN                   NaN                  NaN
# 9                         NaN                   NaN                  NaN
# 10                        NaN                   NaN                  NaN
# 11                        NaN                   NaN                  NaN
# 12                        NaN                   NaN                  NaN
# 13                        NaN                   NaN                  NaN
# 14                        NaN                   NaN                  NaN
# 15                        NaN                   NaN                  NaN
# 16                        NaN                   NaN                  NaN
# 17                        NaN                   NaN                  NaN
# 18                        NaN                   NaN                  NaN
# 19                        NaN                   NaN                  NaN
#
#     TARGET  SK_ID_CURR
# 0      1.0      100002
# 1      0.0      100003
# 2      0.0      100004
# 3      0.0      100006
# 4      0.0      100007
# 5      0.0      100008
# 6      0.0      100009
# 7      0.0      100010
# 8      0.0      100011
# 9      0.0      100012
# 10     0.0      100014
# 11     0.0      100015
# 12     0.0      100016
# 13     0.0      100017
# 14     0.0      100018
# 15     0.0      100019
# 16     0.0      100020
# 17     0.0      100021
# 18     0.0      100022
# 19     0.0      100023
#
# [20 rows x 202 columns]

# %%
pip install --upgrade lightgbm
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lightgbm in c:\users\amal9\appdata\roaming\python\python311\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\amal9\appdata\roaming\python\python311\site-packages (from lightgbm) (2.0.0)
# Requirement already satisfied: scipy in c:\users\amal9\appdata\roaming\python\python311\site-packages (from lightgbm) (1.13.1)
# [notice] A new release of pip is available: 23.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install nest_asyncio
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: nest_asyncio in c:\users\amal9\appdata\roaming\python\python311\site-packages (1.6.0)
# [notice] A new release of pip is available: 23.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nest_asyncio.apply()

def predict(customer_id):

    customer_df = df[df.SK_ID_CURR == customer_id]

    if customer_df.shape[0] == 0:
        return -1
    X = customer_df.iloc[:, :-2]
    score = model.predict_proba(X)[0 , 1]
    return round(score*100, 2)

app = FastAPI()

class post_data(BaseModel):
    customer_id : int

@app.get('/')
async def root():
    return {"Message": "Welcome to Score Prediction API."}

@app.post("/predict")
def score(input_data:post_data):
    score = predict(input_data.customer_id)
    return {"score": score}

if __name__ == "__main__":
    config = uvicorn.Config(app, host="127.0.0.1", port=8000, log_level="info")
    server = uvicorn.Server(config)
    asyncio.run(server.serve())
# Out:
# INFO:     Started server process [55916]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:56285 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56285 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:56296 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56296 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56322 - "POST /predict HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [55916]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 30
#      28 config = uvicorn.Config(app, host="127.0.0.1", port=8000, log_level="info")
#      29 server = uvicorn.Server(config)
# ---> 30 asyncio.run(server.serve())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File c:\Program Files\Python311\Lib\asyncio\events.py:80, in Handle._run(self)
#      78 def _run(self):
#      79     try:
# ---> 80         self._context.run(self._callback, *self._args)
#      81     except (SystemExit, KeyboardInterrupt):
#      82         raise
#
# File c:\Program Files\Python311\Lib\asyncio\tasks.py:350, in Task.__wakeup(self, future)
#     342     self.__step(exc)
#     343 else:
#     344     # Don't pass the value of `future.result()` explicitly,
#     345     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)
#     348     # instead of `__next__()`, which is slower for futures
#     349     # that return non-generator iterators from their `__iter__`.
# --> 350     self.__step()
#     351 self = None
#
# File c:\Program Files\Python311\Lib\asyncio\tasks.py:267, in Task.__step(***failed resolving arguments***)
#     263 try:
#     264     if exc is None:
#     265         # We use the `send` method directly, because coroutines
#     266         # don't have `__iter__` and `__next__` methods.
# --> 267         result = coro.send(None)
#     268     else:
#     269         result = coro.throw(exc)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py:68, in Server.serve(self, sockets)
#      67 async def serve(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 68     with self.capture_signals():
#      69         await self._serve(sockets)
#
# File c:\Program Files\Python311\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py:328, in Server.capture_signals(self)
#     324 # If we did gracefully shut down due to a signal, try to
#     325 # trigger the expected behaviour now; multiple signals would be
#     326 # done LIFO, see https://stackoverflow.com/questions/48434964
#     327 for captured_signal in reversed(self._captured_signals):
# --> 328     signal.raise_signal(captured_signal)
#
# KeyboardInterrupt:
